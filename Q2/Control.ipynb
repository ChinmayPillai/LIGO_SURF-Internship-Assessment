# %%
import control as ct
import matplotlib.pyplot as plt

a = -1 / (8935 * 100)

sys = ct.ss(a, -a, 1, 0)

time = [i*10000 for i in range(10000)]

t, x = ct.input_output_response(sys, time, U=300.0, X0=400.0)

plt.plot(t, x)

# %%
plt.plot(T, yout)

# %%
import numpy as np

# %%
time = [i*10000 for i in range(10000)]

# %%
temp = np.random.normal(loc=300.0, scale=10.0, size=10000)
print(temp)
# Out:
# [296.66903404 299.08161943 298.13370632 ... 302.08673933 303.51377255
#  287.13110937]

# %%
print(temp.shape)
# Out:
# (10000,)

# %%
T, yout = ct.input_output_response(sys, time, U = temp , X0=300.0)

# %%
plt.plot(T, yout)

# %%
plt.plot(T, temp)
